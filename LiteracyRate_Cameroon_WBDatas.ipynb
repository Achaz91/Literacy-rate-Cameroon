# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv("https://data.humdata.org/dataset/77cddd6c-aaed-4270-9d51-482877fae57d/resource/ff24c63c-4145-4cfa-8684-2c4b16f4ea26/download/gender_cmr.csv")
# df = pd.read_csv('datasets/humdata/gender_cmr.csv')
df = df.drop(index=0)
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df['Value'] = df['Value'].astype('float')
df.head()
# Out:
#   Country Name Country ISO3       Year  \
# 1     Cameroon          CMR 2016-01-01
# 2     Cameroon          CMR 2009-01-01
# 3     Cameroon          CMR 2016-01-01
# 4     Cameroon          CMR 2009-01-01
# 5     Cameroon          CMR 2006-01-01
#
#                                       Indicator Name  Indicator Code  Value
# 1         Firms with female top manager (% of firms)  IC.FRM.FEMM.ZS   22.9
# 2         Firms with female top manager (% of firms)  IC.FRM.FEMM.ZS   10.0
# 3  Firms with female participation in ownership (...  IC.FRM.FEMO.ZS   39.7
# 4  Firms with female participation in ownership (...  IC.FRM.FEMO.ZS   15.7
# 5  Firms with female participation in ownership (...  IC.FRM.FEMO.ZS   35.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6768 entries, 1 to 6768
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    6768 non-null   object
#  1   Country ISO3    6768 non-null   object
#  2   Year            6768 non-null   datetime64[ns]
#  3   Indicator Name  6768 non-null   object
#  4   Indicator Code  6768 non-null   object
#  5   Value           6768 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 317.4+ KB

# %%
# 'SE.ADT.1524.LT.FE.ZS' : Literacy rate, youth female (% of females ages 15-24)
# 'SE.ADT.1524.LT.MA.ZS' : Literacy rate, youth male (% of males ages 15-24)
indicators = ['SE.ADT.1524.LT.FE.ZS', 'SE.ADT.1524.LT.MA.ZS']

df_ind = df[df['Indicator Code'].isin(indicators)]

sns.lineplot(data=df_ind, x='Year', y='Value', hue='Indicator Code', marker='o')

plt.title("Literacy rate, youth (ages 15-24) : Cameroon")
plt.xlabel('Year')
plt.ylabel('rate (%)')
plt.axvspan('2000', '2007', color='green', alpha=0.3)
plt.axvspan('2009', '2012', color='green', alpha=0.3)
plt.axvspan('2014', '2019', color='green', alpha=0.3)
# plt.legend(title='Genders', labels=['Female', 'Male'])
plt.show()
